# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/somministrazioni-vaccini-latest.csv')
df.data_somministrazione = pd.to_datetime(df.data_somministrazione)
df.sort_values('data_somministrazione', inplace=True)
df = df[df['data_somministrazione']>='2021-01-01']
df['giorno_campagna'] = df.data_somministrazione.dt.dayofyear
df.head()
# Out:
#     data_somministrazione        fornitore area fascia_anagrafica  \
# 450            2021-01-01  Pfizer/BioNTech  SIC             20-29
# 453            2021-01-01  Pfizer/BioNTech  SIC             50-59
# 455            2021-01-01  Pfizer/BioNTech  SIC             70-79
# 452            2021-01-01  Pfizer/BioNTech  SIC             40-49
# 451            2021-01-01  Pfizer/BioNTech  SIC             30-39
#
#      sesso_maschile  sesso_femminile  \
# 450              63               75
# 453             100               91
# 455               8                1
# 452              95               84
# 451              81               85
#
#      categoria_operatori_sanitari_sociosanitari  \
# 450                                         132
# 453                                         168
# 455                                           9
# 452                                         163
# 451                                         153
#
#      categoria_personale_non_sanitario  categoria_ospiti_rsa  \
# 450                                  6                     0
# 453                                 23                     0
# 455                                  0                     0
# 452                                 16                     0
# 451                                 13                     0
#
#      categoria_over80  categoria_forze_armate  categoria_personale_scolastico  \
# 450                 0                       0                               0
# 453                 0                       0                               0
# 455                 0                       0                               0
# 452                 0                       0                               0
# 451                 0                       0                               0
#
#      prima_dose  seconda_dose codice_NUTS1 codice_NUTS2  codice_regione_ISTAT  \
# 450         138             0          ITG         ITG1                    19
# 453         191             0          ITG         ITG1                    19
# 455           9             0          ITG         ITG1                    19
# 452         179             0          ITG         ITG1                    19
# 451         166             0          ITG         ITG1                    19
#
#     nome_area  giorno_campagna
# 450   Sicilia                1
# 453   Sicilia                1
# 455   Sicilia                1
# 452   Sicilia                1
# 451   Sicilia                1

# %%
pop = pd.read_html('https://it.wikipedia.org/wiki/Demografia_d%27Italia', thousands='.')[11]
pop = pop[['Età', 'Totale']]
pop.drop(index=101, axis=0, inplace=True)
pop.Totale = pd.to_numeric(pop.Totale)
pop['Età'] = pd.to_numeric(pop['Età'].str.split(' ', expand=True)[0])

def ages(s):
    if (s['Età'] >= 0 and s['Età'] < 16):
        return '0-16'
    elif (s['Età'] >= 16 and s['Età'] <= 19):
        return '16-19'
    elif (s['Età'] >= 20 and s['Età'] <= 29):
        return '20-29'
    elif (s['Età'] >= 30 and s['Età'] <= 39):
        return '30-39'
    elif (s['Età'] >= 40 and s['Età'] <= 49):
        return '40-49'
    elif (s['Età'] >= 50 and s['Età'] <= 59):
        return '50-59'
    elif (s['Età'] >= 60 and s['Età'] <= 69):
        return '60-69'
    elif (s['Età'] >= 70 and s['Età'] <= 79):
        return '70-79'
    elif (s['Età'] >= 80 and s['Età'] <= 89):
        return '80-89'
    elif s['Età'] >= 90:
        return '90+'
    
pop['gruppo'] = pop.apply(ages, axis=1)

# %%
pop
# Out:
#      Età  Totale gruppo
# 0      0  532991   0-16
# 1      1  542019   0-16
# 2      2  553729   0-16
# 3      3  561994   0-16
# 4      4  559203   0-16
# ..   ...     ...    ...
# 96    96   30447    90+
# 97    97   22450    90+
# 98    98   15624    90+
# 99    99   10192    90+
# 100  100   15080    90+
#
# [101 rows x 3 columns]
